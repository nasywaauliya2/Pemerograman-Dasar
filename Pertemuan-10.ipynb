# %% [markdown]
# <a href="https://colab.research.google.com/github/nasywaauliya2/Pemerograman-Dasar/blob/main/Pertemuan-10.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# Memuat tabel customers

# %%
customers_df =pd.read_csv("/content/drive/MyDrive/Matakuliah Pemegroraman Dasar/Data_10/customers.csv")
customers_df.head()
# Out:
#    customer_id customer_name             gender  age  \
# 0            1       fulan 1             Female   30
# 1            2       fulan 2  Prefer not to say   69
# 2            3       fulan 3  Prefer not to say   59
# 3            4       fulan 4  Prefer not to say   67
# 4            5       fulan 5  Prefer not to say   30
#
#                      home_address  zip_code               city  \
# 0  8606 Victoria TerraceSuite 560      5464      Johnstonhaven
# 1      8327 Kirlin SummitApt. 461      8223    New Zacharyfort
# 2       269 Gemma SummitSuite 109      5661           Aliburgh
# 3       743 Bailey GroveSuite 141      1729  South Justinhaven
# 4         48 Hyatt ManorSuite 375      4032     Griffithsshire
#
#                           state    country
# 0            Northern Territory  Australia
# 1               South Australia  Australia
# 2  Australian Capital Territory  Australia
# 3                    Queensland  Australia
# 4                    Queensland  Australia

# %% [markdown]
# Memuat tabel orders

# %%
orders_df =pd.read_csv("/content/drive/MyDrive/Matakuliah Pemegroraman Dasar/Data_10/orders.csv")
orders_df.head()
# Out:
#    order_id  customer_id  payment order_date delivery_date
# 0         1           64    30811  2021-8-30    2021-09-24
# 1         2          473    50490   2021-2-3    2021-02-13
# 2         3          774    46763  2021-10-8    2021-11-03
# 3         4          433    39782   2021-5-6    2021-05-19
# 4         5          441    14719  2021-3-23    2021-03-24

# %% [markdown]
# memuat tables product

# %%
products_df =pd.read_csv("/content/drive/MyDrive/Matakuliah Pemegroraman Dasar/Data_10/products.csv")
products_df.head()
# Out:
#    product_id product_type  product_name size colour  price  quantity  \
# 0           0        Shirt  Oxford Cloth   XS    red    114        66
# 1           1        Shirt  Oxford Cloth    S    red    114        53
# 2           2        Shirt  Oxford Cloth    M    red    114        54
# 3           3        Shirt  Oxford Cloth    L    red    114        69
# 4           4        Shirt  Oxford Cloth   XL    red    114        47
#
#                                     description
# 0  A red coloured, XS sized, Oxford Cloth Shirt
# 1   A red coloured, S sized, Oxford Cloth Shirt
# 2   A red coloured, M sized, Oxford Cloth Shirt
# 3   A red coloured, L sized, Oxford Cloth Shirt
# 4  A red coloured, XL sized, Oxford Cloth Shirt

# %% [markdown]
# Memuat tabel sales

# %%
sales_df =pd.read_csv("/content/drive/MyDrive/Matakuliah Pemegroraman Dasar/Data_10/sales.csv")
sales_df.head()
# Out:
#    sales_id  order_id  product_id  price_per_unit  quantity  total_price
# 0         0         1         218             106         2        212.0
# 1         1         1         481             118         1        118.0
# 2         2         1           2              96         3        288.0
# 3         3         1        1002             106         2        212.0
# 4         4         1         691             113         3        339.0

# %% [markdown]
# **Assessing** **Data** saat ini kita masuk ke tahap kedua dalam proses data wrangling yaitu assessing data.

# %% [markdown]
# **Menilai Data customers_df** Data pertama yang akan kita analisis adalah customers_df. Untuk melihat gambaran awal dari data ini, apakah ada nilai kosong—kita bisa menggunakan method info().

# %%
customers_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1007 entries, 0 to 1006
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   customer_id    1007 non-null   int64
#  1   customer_name  1007 non-null   object
#  2   gender         989 non-null    object
#  3   age            1007 non-null   int64
#  4   home_address   1007 non-null   object
#  5   zip_code       1007 non-null   int64
#  6   city           1007 non-null   object
#  7   state          1007 non-null   object
#  8   country        1007 non-null   object
# dtypes: int64(3), object(6)
# memory usage: 70.9+ KB

# %% [markdown]
# ketika di perhatikan, tidak ada perbedaan dan masalah dengan tipe data dari seluruh kolom. tetapi, terdapat sedikit perbedaan di kolom gender hal ini menunjukkan adanya missing values pada kolom gender. Nah, untuk memastikan hal ini, jalankan kode berikut.

# %%
customers_df.isna().sum()
# Out:
# customer_id       0
# customer_name     0
# gender           18
# age               0
# home_address      0
# zip_code          0
# city              0
# state             0
# country           0
# dtype: int64

# %% [markdown]
# Terdapat 18 data yang hilang atau missing value pada kolom gender. Ini yang akan tangani pada tahap data cleaning

# %% [markdown]
# Masalah selanjutnya yang harus kita periksa ialah duplikasi data. Dengan menggunakan method df.duplicated() Untuk memeriksa hal ini, kita bisa menjalankan kode berikut.

# %%
print("Jumlah duplikasi: ", customers_df.duplicated().sum())
# Out:
# Jumlah duplikasi:  6

# %% [markdown]
# Ketika menjalankan kode di atas, kita akan menemukan 6 data yang terduplikat. Pada tahap data cleaning nanti, kita akan menghilangkan semua duplikasi tersebut.

# %% [markdown]
# Selanjutnya, kita akan mengecek parameter statistik dari kolom numerik yang ada di customers_df. Supaya lebih mudah dan cepat, kita bisa menggunakan method describe(). Method ini akan menampilkan ringkasan statistik seperti nilai rata-rata (mean), median, standar deviasi, nilai minimum, dan maksimum dari setiap kolom numerik dalam DataFrame. Berikut adalah contoh cara penggunaannya.

# %%
customers_df.describe()
# Out:
#        customer_id          age     zip_code
# count  1007.000000  1007.000000  1007.000000
# mean    501.726912    50.929494  5012.538232
# std     288.673238    30.516299  2885.836112
# min       1.000000    20.000000     2.000000
# 25%     252.500000    34.000000  2403.500000
# 50%     502.000000    50.000000  5087.000000
# 75%     751.500000    65.000000  7493.500000
# max    1000.000000   700.000000  9998.000000

# %% [markdown]
# Jika dilihat lebih lanjut, terdapat kejanggalan pada nilai maksimum di kolom age, karena angkanya tidak masuk akal untuk usia manusia. Hal ini kemungkinan terjadi akibat adanya data yang tidak akurat atau salah input pada kolom tersebut. Oleh karena itu, data ini akan kita perbaiki dan bersihkan pada tahap data cleaning agar analisis selanjutnya lebih akurat.

# %% [markdown]
# Menilai Data orders_df
#
# Selanjutnya kita akan menilai data pada orders_df. Mulai dengan memeriksa tipe data dari tiap kolom menggunakan method info().

# %%
orders_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   order_id       1000 non-null   int64
#  1   customer_id    1000 non-null   int64
#  2   payment        1000 non-null   int64
#  3   order_date     1000 non-null   object
#  4   delivery_date  1000 non-null   object
# dtypes: int64(3), object(2)
# memory usage: 39.2+ KB

# %% [markdown]
# Jika diperhatikan, jumlah data pada orders_df sudah lengkap, artinya tidak terdapat missing value di dalam dataset tersebut. Namun, masih ditemukan masalah pada tipe data kolom order_date dan delivery_date. Kedua kolom ini seharusnya menggunakan tipe data datetime, bukan object (yang biasanya digunakan untuk data berupa string). Oleh karena itu, perlu dilakukan perubahan tipe data agar sesuai dan memudahkan analisis selanjutnya.

# %% [markdown]
# Berikutnya, perlu memeriksa duplikasi dan ringkasan parameter statistik dari kolom numerik pada orders_df

# %%
print("Jumlah duplikasi: ",orders_df.duplicated().sum())
# Out:
# Jumlah duplikasi:  0

# %%
orders_df.describe()
# Out:
#           order_id  customer_id       payment
# count  1000.000000  1000.000000   1000.000000
# mean    500.500000   506.640000  33972.936000
# std     288.819436   277.115502  14451.609047
# min       1.000000     1.000000  10043.000000
# 25%     250.750000   275.250000  21329.250000
# 50%     500.500000   515.000000  33697.500000
# 75%     750.250000   737.250000  46249.000000
# max    1000.000000  1000.000000  59910.000000

# %% [markdown]
# Jika diperhatikan, tidak ada keanehan pada hasil tersebut. Ini menunjukkan tidak terdapat duplikasi dan keanehan nilai pada orders_df.

# %% [markdown]
# **Menilai Data product_df**
#
# Selanjutnya, kita akan mengecek data pada product_df. Langkah pertama yang dilakukan adalah menggunakan method info().

# %%
products_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1266 entries, 0 to 1265
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   product_id    1266 non-null   int64
#  1   product_type  1266 non-null   object
#  2   product_name  1266 non-null   object
#  3   size          1266 non-null   object
#  4   colour        1266 non-null   object
#  5   price         1266 non-null   int64
#  6   quantity      1266 non-null   int64
#  7   description   1266 non-null   object
# dtypes: int64(3), object(5)
# memory usage: 79.3+ KB

# %% [markdown]
# Berdasarkan hasil tersebut, dapat disimpulkan bahwa tidak terdapat masalah pada tipe data tiap kolom dalam product_df. Selain itu, jumlah datanya juga telah lengkap sehingga tidak ada missing value di dalamnya

# %%
print("Jumlah duplikasi: ", products_df.duplicated().sum())
# Out:
# Jumlah duplikasi:  6

# %%
products_df.describe()
# Out:
#         product_id        price     quantity
# count  1266.000000  1266.000000  1266.000000
# mean    627.926540   105.812006    60.138231
# std     363.971586     9.715611    11.682791
# min       0.000000    90.000000    40.000000
# 25%     313.250000    95.250000    50.000000
# 50%     626.500000   109.000000    60.000000
# 75%     942.750000   114.000000    70.000000
# max    1259.000000   119.000000    80.000000

# %% [markdown]
# Berdasarkan data di atas, dapat dilihat bahwa terdapat 6 data yang terduplikasi pada product_df. Pada tahap cleaning data, kita akan menghapus duplikasi tersebut.

# %% [markdown]
# Data terakhir yang akan kita nilai adalah sales_df. Sebagai langkah awal, kita akan menggunakan method info() untuk melihat gambaran umum dataset, seperti jumlah data, nama kolom, serta tipe data pada setiap kolom. Dengan pengecekan ini, kita bisa mengetahui apakah data di sales_df sudah sesuai atau masih perlu dilakukan perbaikan sebelum masuk ke tahap analisis selanjutnya.

# %%
sales_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   sales_id        5000 non-null   int64
#  1   order_id        5000 non-null   int64
#  2   product_id      5000 non-null   int64
#  3   price_per_unit  5000 non-null   int64
#  4   quantity        5000 non-null   int64
#  5   total_price     4981 non-null   float64
# dtypes: float64(1), int64(5)
# memory usage: 234.5 KB

# %% [markdown]
# Berdasarkan hasil di atas, tidak ada masalah pada tipe data tiap kolom dalam sales_df. Namun, terdapat keanehan pada jumlah data pada kolom total_price. Hal ini menunjukkan adanya missing value pada kolom tersebut.

# %%
sales_df.isna().sum()
# Out:
# sales_id           0
# order_id           0
# product_id         0
# price_per_unit     0
# quantity           0
# total_price       19
# dtype: int64

# %% [markdown]
# Kode di atas akan menunjukkan jumlah missing value dari setiap kolom dalam sales_df. Berikut merupakan hasil yang kita peroleh.

# %% [markdown]
# Berdasarkan hasil di atas, dapat disimpulkan bahwa terdapat 19 missing value pada kolom total_price. Hal ini akan kita bersihkan pada tahap cleaning data.

# %% [markdown]
# selanjutnya adalah memeriksa duplikasi dan ringkasan parameter statistik dari sales_df

# %%
print("Jumlah duplikasi: ", sales_df.duplicated().sum())
# Out:
# Jumlah duplikasi:  0

# %%
sales_df.describe()
# Out:
#           sales_id     order_id   product_id  price_per_unit    quantity  \
# count  5000.000000  5000.000000  5000.000000     5000.000000  5000.00000
# mean   2499.500000   503.038200   634.053200      103.501600     1.99240
# std    1443.520003   285.964418   363.255794        9.195004     0.80751
# min       0.000000     1.000000     1.000000       90.000000     1.00000
# 25%    1249.750000   258.000000   323.000000       95.000000     1.00000
# 50%    2499.500000   504.500000   635.000000      102.000000     2.00000
# 75%    3749.250000   749.000000   951.000000      112.000000     3.00000
# max    4999.000000   999.000000  1259.000000      119.000000     3.00000
#
#        total_price
# count  4981.000000
# mean    206.307368
# std      86.352449
# min      90.000000
# 25%     112.000000
# 50%     204.000000
# 75%     285.000000
# max     357.000000

# %% [markdown]
# Berdasarkan hasil yang diperoleh, dapat diketahui bahwa tidak terdapat data duplikat pada sales_df. Selain itu, ringkasan parameter statistik yang ditampilkan juga tidak menunjukkan kejanggalan, sehingga data pada sales_df dapat dikatakan cukup baik dan siap digunakan untuk analisis selanjutnya.

# %% [markdown]
# sampai tahap ini, kita telah berhasil mengidentifikasi berbagai masalah pada data yang telah kita kumpulkan. Berikut merupakan rangkumannya.

# %% [markdown]
# Cleaning Data

# %% [markdown]
# Membersihkan Data customers_df
#
# Berdasarkan hasil proses assessing data yang telah dilakukan sebelumnya, diketahui bahwa terdapat tiga permasalahan utama pada customers_df, yaitu adanya data duplikat, nilai kosong (missing value), serta data yang tidak akurat (inaccurate value). Oleh karena itu, diperlukan proses data cleaning untuk mengatasi masalah tersebut agar data dapat digunakan secara optimal pada tahap analisis selanjutnya.

# %% [markdown]
# Menghilangkan Duplicate Data
#
# Untuk mengatasi masalah data duplikat, kita bisa menggunakan method drop_duplicates(). Method ini berfungsi untuk menghapus baris data yang sama atau berulang dalam customers_df, sehingga setiap data yang tersisa bersifat unik. Berikut ini merupakan contoh kode yang digunakan untuk menghilangkan duplikasi pada customers_df.

# %%
customers_df.drop_duplicates(inplace=True)

# %% [markdown]
# Setelah menjalankan kode di atas, periksa kembali apakah masih terdapat duplikasi pada data tersebut dengan menjalankan kode berikut.

# %%
print("Jumlah duplikasi: ", customers_df.duplicated().sum())
# Out:
# Jumlah duplikasi:  0

# %% [markdown]
# Jika proses penghapusan duplikasi berjalan lancar, kode di atas akan menghasilkan keluaran yang menunjukkan tidak adanya duplikasi pada customers_df.

# %% [markdown]
# Menangani missing value

# %% [markdown]
# Masalah selanjutnya yang perlu kita tangani adalah missing value pada kolom gender. Secara umum, ada tiga metode yang bisa digunakan untuk mengatasi missing value, yaitu dropping (menghapus data), imputation (mengisi nilai yang hilang), dan interpolation (perkiraan berdasarkan pola data).
# Untuk menentukan metode yang paling tepat, kita perlu terlebih dahulu melihat data yang mengandung missing value tersebut. Hal ini bisa dilakukan dengan menggunakan teknik filtering, seperti pada contoh berikut.

# %%
customers_df[customers_df.gender.isna()]
# Out:
#      customer_id customer_name gender  age                     home_address  \
# 38            39      fulan 39    NaN   80  7440 Cameron Estate DrSuite 628
# 167          168     fulan 168    NaN   27         2781 Berge MallSuite 452
# 322          322     fulan 322    NaN   30        593 Becker CircleApt. 333
# 393          393     fulan 393    NaN   34          5158 Levi HillSuite 531
# 442          442     fulan 442    NaN   26           5157 Feil RoadApt. 633
# 722          720     fulan 720    NaN   40         31 Jordan ParadeApt. 400
# 745          743     fulan 743    NaN   57   09 Christopher StreetSuite 967
# 773          771     fulan 771    NaN   74     7367 Wright JunctionApt. 773
# 798          795     fulan 795    NaN   49          487 Summer MewsApt. 874
# 801          798     fulan 798    NaN   56           27 Aiden KnollApt. 875
# 825          822     fulan 822    NaN   59        41 Jenkins KnollSuite 438
# ...

# %% [markdown]
# Kode di atas berfungsi untuk menampilkan data tertentu saja, yaitu baris-baris pada customers_df yang memiliki nilai kosong (missing value) pada kolom gender. Dengan kata lain, kode customers_df.gender.isna() digunakan untuk memfilter dan menampilkan hanya data yang kolom gender-nya belum terisi.

# %% [markdown]
# Berdasarkan hasil yang diperoleh, dapat diketahui bahwa nilai yang paling sering muncul pada kolom gender adalah “Prefer not to say”. Oleh karena itu, nilai ini akan digunakan untuk mengisi missing value pada kolom tersebut. Proses pengisian nilai kosong ini dapat dilakukan dengan menggunakan method fillna(), seperti pada contoh kode berikut.

# %% [markdown]
# Untuk memastikan proses di atas berjalan dengan semestinya, kita bisa menjalankan kembali kode untuk mengidentifikasi missing value seperti berikut.

# %%
customers_df.isna().sum()
# Out:
# customer_id       0
# customer_name     0
# gender           18
# age               0
# home_address      0
# zip_code          0
# city              0
# state             0
# country           0
# dtype: int64

# %% [markdown]
# **Menangani Inaccurate Value**
#
# Selanjutnya, kita akan menangani masalah inaccurate value pada kolom age. Sebagai langkah awal, kita perlu melihat baris data yang mengandung nilai tidak wajar tersebut, yaitu baris dengan nilai age paling besar (maksimum). Untuk menampilkannya, kita bisa menggunakan teknik filtering, seperti pada contoh kode berikut.

# %%
customers_df[customers_df.age == customers_df.age.max()]
# Out:
#      customer_id customer_name             gender  age  \
# 967          961     fulan 961  Prefer not to say  700
#
#                    home_address  zip_code        city            state  \
# 967  29 Farrell ParadeSuite 818      6528  New Joseph  South Australia
#
#        country
# 967  Australia

# %% [markdown]
# Kode di atas akan menampilkan baris data yang memiliki nilai age maksimum.

# %% [markdown]
# Berdasarkan data tersebut, kita bisa berasumsi bahwa **inaccurate value** tersebut terjadi karena **human error** sehingga kelebihan memasukkan nilai nol. Oleh karena itu, gantilah dengan **nilai 70** . Proses ini dilakukan dengan memanfaatkan **method** `replace()`seperti contoh berikut.

# %%
customers_df.age.replace(customers_df.age.max(), 70, inplace=True)
# Out:
# /tmp/ipython-input-4147959128.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   customers_df.age.replace(customers_df.age.max(), 70, inplace=True)

# %%
customers_df[customers_df.age == customers_df.age.max()]
# Out:
#      customer_id customer_name             gender  age  \
# 17            18      fulan 18               Male   79
# 27            28      fulan 28  Prefer not to say   79
# 47            48      fulan 48               Male   79
# 68            69      fulan 69  Prefer not to say   79
# 73            74      fulan 74  Prefer not to say   79
# 151          152     fulan 152             Female   79
# 209          210     fulan 210  Prefer not to say   79
# 211          212     fulan 212  Prefer not to say   79
# 219          220     fulan 220  Prefer not to say   79
# 303          304     fulan 304  Prefer not to say   79
# 404          404     fulan 404  Prefer not to say   79
# 444          444     fulan 444  Prefer not to say   79
# 561          560     fulan 560  Prefer not to say   79
# 643          642     fulan 642  Prefer not to say   79
# 679          678     fulan 678  Prefer not to say   79
# 682          681     fulan 681  Prefer not to say   79
# ...

# %%
customers_df.age.replace(customers_df.age.max(), 50, inplace=True)
# Out:
# /tmp/ipython-input-606824494.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   customers_df.age.replace(customers_df.age.max(), 50, inplace=True)

# %%
customers_df[customers_df.age == customers_df.age.max()]
# Out:
#      customer_id customer_name             gender  age  \
# 11            12      fulan 12  Prefer not to say   78
# 62            63      fulan 63  Prefer not to say   78
# 87            88      fulan 88               Male   78
# 97            98      fulan 98             Female   78
# 172          173     fulan 173  Prefer not to say   78
# 217          218     fulan 218  Prefer not to say   78
# 223          224     fulan 224  Prefer not to say   78
# 250          251     fulan 251             Female   78
# 258          259     fulan 259  Prefer not to say   78
# 337          337     fulan 337  Prefer not to say   78
# 403          403     fulan 403  Prefer not to say   78
# 405          405     fulan 405               Male   78
# 469          469     fulan 469             Female   78
# 500          500     fulan 500  Prefer not to say   78
# 539          539     fulan 539               Male   78
# 614          613     fulan 613  Prefer not to say   78
# ...

# %% [markdown]
# Pastikan lagi bahwa tidak ada data yang inaccurate pada kolom age

# %%
customers_df.describe()
# Out:
#        customer_id          age     zip_code
# count  1001.000000  1001.000000  1001.000000
# mean    500.942058    49.164835  5000.693307
# std     289.013599    16.933157  2886.084454
# min       1.000000    20.000000     2.000000
# 25%     251.000000    34.000000  2398.000000
# 50%     501.000000    50.000000  5079.000000
# 75%     751.000000    64.000000  7454.000000
# max    1000.000000    78.000000  9998.000000

# %% [markdown]
# Berdasarkan hasil tersebut dapat dilihat bahwa kolom **age** memiliki **nilai maksimum** yang cukup masuk akal. Selain itu, jika Ada perhatikan, nilai **mean dan standard deviation** ikut berubah setelah kita menangani inaccurate value tersebut.

# %% [markdown]
# **Membersihkan Data orders_df**
# Sekarang kita telah menyelesaikan semua permasalahan yang ada pada `customers_df`. Selanjutnya, kita akan mengatasi permasalahan pada `orders_df`. Berdasarkan proses assessing data sebelumnya, diketahui bahwa terdapat kesalahan tipe data untuk kolom `order_date & delivery_date`.

# %% [markdown]
# Untuk mengatasi masalah ini, kita akan mengganti tipe data pada kolom order_date & delivery_date menjadi datetime. Proses ini dapat dilakukan menggunakan function to_datetime() yang disediakan oleh library pandas

# %%
datetime_columns = ["order_date", "delivery_date"]

# %% [markdown]
# Kode di atas akan mengubah tipe data pada kolom `order_date & delivery_date` menjadi `datetime`. Untuk memastikan hal ini berjalan sesuai harapan, periksa kembali tipe data tersebut menggunakan method `info()`.

# %%
orders_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   order_id       1000 non-null   int64
#  1   customer_id    1000 non-null   int64
#  2   payment        1000 non-null   int64
#  3   order_date     1000 non-null   object
#  4   delivery_date  1000 non-null   object
# dtypes: int64(3), object(2)
# memory usage: 39.2+ KB

# %% [markdown]
# Jika semua tahapan berjalan sesuai harapanm, Maka tipe data kedua kolom sudah berganti menjadi **datetime**

# %% [markdown]
# **Membersihkan Data product_df**

# %% [markdown]
# Data berikutnya yang akan bersihkan ialah **product_df**. Sesuai hasil assessing data sebelumnya, kita mengetahui bahwa terdapat `6 data` yang **terduplikasi** pada **product_df.** Untuk mengatasi hal ini, kita perlu membuang data yang sama tersebut menggunakan **method** `drop_duplicates()` seperti contoh berikut.

# %%
products_df.drop_duplicates(inplace=True)

# %% [markdown]
# Kode di atas akan menghapus semua data yang duplikat. Untuk memastikan kode tersebut berjalan sesuai harapan, jalankanlah kode berikut.

# %%
print("Jumlah duplikasi: ", products_df.duplicated().sum())
# Out:
# Jumlah duplikasi:  0

# %% [markdown]
# Jika proses penghapusan data yang duplikat berjalan dengan lancar, kode di atas akan menghasilkan keluaran seperti berikut **“Jumlah duplikasi:  0”**.

# %% [markdown]
# **Membersihkan Data sales_df**
#
# Data selanjutnya yang perlu bersihkan ialah sales_df. Berdasarkan hasil penilain data sebelumnya, diketahui bahwa terdapat 19 missing value pada kolom total_price. Untuk mengetahui proses penanganan missing value yang paling sesuai, kita perlu melihat terlebih dahulu baris data yang mengandung missing value tersebut.

# %%
sales_df[sales_df.total_price.isna()]
# Out:
#       sales_id  order_id  product_id  price_per_unit  quantity  total_price
# 9            9         2        1196             105         1          NaN
# 121        121        27        1027              90         3          NaN
# 278        278        63         360              94         2          NaN
# 421        421        95        1091             115         1          NaN
# 489        489       108        1193             105         3          NaN
# 539        539       117         405             119         2          NaN
# 636        636       134         653              93         3          NaN
# 687        687       145        1138             102         1          NaN
# 854        854       177          64             104         1          NaN
# 1079      1079       222         908              94         3          NaN
# 1193      1193       248        1121             102         2          NaN
# ...

# %% [markdown]
# Kode di atas akan menampilkan semua baris data yang memiliki **missing value** pada kolom `total_price` seperti pada gambar di atas.

# %% [markdown]
# Berdasarkan tampilan data tersebut, kita menemukan bahwa nilai `total_price` merupakan hasil **perkalian** antara `price_per_unit dan quantity`.
#
# Kita dapat menggunakan pola ini untuk menangani missing value pada kolom `total_price`. Berikut merupakan contoh penerapan kode untuk melakukannya.

# %%
sales_df["total_price"] = sales_df["price_per_unit"] * sales_df["quantity"]

# %% [markdown]
# Kode di atas akan **mengatasi** seluruh `missing value` serta memastikan nilai pada kolom `total_price` telah sesuai. Untuk memastikan hal ini, Anda dapat memeriksa kembali **jumlah missing value** pada `sales_df `menggunakan kode berikut.

# %%
sales_df.isna().sum()
# Out:
# sales_id          0
# order_id          0
# product_id        0
# price_per_unit    0
# quantity          0
# total_price       0
# dtype: int64

# %% [markdown]
# Jika proses sebelumnya berjalan lancar, Anda akan menemukan hasil seperti gambar di atas.

# %% [markdown]
# Tahapan di atas adalah Proses data wrangling untuk menyiapkan data sebelum dianalisis

# %% [markdown]
# **Exploratory Data Analysis**

# %% [markdown]
# Seperti yang telah kita bahas sebelumnya, untuk menentukan sebuah pertanyaan, kita perlu memahami permasalahan bisnis yang dihadapi terlebih dahulu. Nah, pada proyek ini, kita dihadapkan dengan sebuah contoh kasus dari perusahaan online fashion bernama Fashion Collection (FCO).
#
# Sebagai perusahaan yang bergerak di bidang online fashion, Fashion Collection (FCO) perlu mengevaluasi performa penjualan (sales) dan memahami item fashion yang paling banyak dibeli. Selain itu, ia juga perlu lebih memahami pelanggannya (customer) sehingga dapat membuat sebuah strategi campaign yang lebih efisien.

# %%
customers_df.describe(include="all")
# Out:
#         customer_id customer_name             gender          age  \
# count   1001.000000          1001                983  1001.000000
# unique          NaN          1000                  3          NaN
# top             NaN     fulan 943  Prefer not to say          NaN
# freq            NaN             2                725          NaN
# mean     500.942058           NaN                NaN    49.164835
# std      289.013599           NaN                NaN    16.933157
# min        1.000000           NaN                NaN    20.000000
# 25%      251.000000           NaN                NaN    34.000000
# 50%      501.000000           NaN                NaN    50.000000
# 75%      751.000000           NaN                NaN    64.000000
# max     1000.000000           NaN                NaN    78.000000
#
#                       home_address     zip_code        city            state  \
# count                         1001  1001.000000        1001             1001
# ...

# %% [markdown]
# **Melakukan Eksplorasi Data**

# %% [markdown]
# **Eksplorasi Data customers_df**
#
# Pertama, kita akan mengeksplorasi data customers_df terlebih dahulu. Seperti yang kita ketahui, dataset ini memuat berbagai informasi terkait customer, seperti customer_id, customer_name, gender, age, home_address, zip_code, city, state, dan country.
#
# melihat rangkuman parameter statistik dari data customers_df menggunakan method `describe()`

# %% [markdown]
# Sekarang coba kita lihat demografi pelanggan berdasarkan jenis kelamin (gender). Untuk melakukan ini, kita akan menggunakan method groupby() yang diikuti dengan method agg(). Berikut contoh kode untuk melakukannya.

# %%
customers_df.groupby(by="gender").agg({
    "customer_id": "nunique",
    "age": ["max", "min", "mean", "std"]
})
# Out:
#                   customer_id age
#                       nunique max min       mean        std
# gender
# Female                    115  78  20  48.643478  16.162655
# Male                      143  78  20  50.139860  17.452794
# Prefer not to say         725  78  20  49.078621  16.983438

# %% [markdown]
# Kode di atas akan menghasilkan sebuah pivot table. Ia memuat informasi jumlah pelanggan (nunique dari customer_id) serta parameter umur yang dikelompokkan berdasarkan jenis kelamin.
#
#
# Berdasarkan pivot table di atas, dapat diketahui bahwa pelanggan yang kita miliki didominasi oleh jenis kelamin prefer not to say. Di lain sisi, distribusi umur mereka ternyata cukup mirip yaitu berkisar antara 20 hingga 80 tahun.

# %%
customers_df.groupby(by="city").customer_id.nunique().sort_values(ascending=False)
# Out:
# city
# East Sophia     3
# New Ava         3
# East Aidan      3
# Lake Sienna     2
# Jademouth       2
#                ..
# Justinport      1
# Kaiberg         1
# Kaifort         1
# Kaihaven        1
# Johnsonhaven    1
# Name: customer_id, Length: 961, dtype: int64

# %%
customers_df.groupby(by="state").customer_id.nunique().sort_values(ascending=False)
# Out:
# state
# South Australia                 139
# Queensland                      134
# New South Wales                 132
# Northern Territory              125
# Western Australia               124
# Australian Capital Territory    121
# Victoria                        121
# Tasmania                        104
# Name: customer_id, dtype: int64

# %% [markdown]
# Berdasarkan hasil di atas, dapat dilihat bahwa persebaran pelanggan kita cukup merata pada setiap kota dan negara bagian. Pelanggan kita paling banyak berada di kota East Aidan, East Sophia, dan New Ava dengan jumlah masing-masing tiga pelanggan. Selain itu, pelanggan kita paling banyak berasal dari negara bagian South Australia.

# %% [markdown]
# Oke, sekarang kita telah memiliki cukup banyak informasi terkait data customers_df. Selanjutnya kita akan melakukan eksplorasi terhadap data orders_df

# %% [markdown]
# **Eksplorasi Data orders_df**

# %% [markdown]
# Data kedua yang akan kita eksplor adalah orders_df. Ia mengandung berbagai informasi terkait sebuah order yang terdiri dari order_id, customer_id, order_date, dan delivery_date

# %% [markdown]
# Berdasarkan informasi tersebut, kita bisa membuat sebuah kolom baru untuk memuat waktu pengiriman tiap order. Untuk melakukannya, kita perlu menghitung selisih antar delivery_date dan order_date serta menyimpannya sebagai delivery_time. Selanjutnya, kita akan menggunakan method apply() untuk melakukan sebuah operasi terhadap setiap elemen dalam sebuah kolom DataFrame atau Series (bentuk satu dimensi dari DataFrame).

# %% [markdown]
# Operasi yang akan kita lakukan ialah menghitung jumlah detik dari delivery_time menggunakan method total_seconds().  selanjutnya diubah ke dalam satuan hari (dibagi 86400) dan diambil bilangan bulatnya

# %%
orders_df['order_date'] = pd.to_datetime(orders_df['order_date'])
orders_df['delivery_date'] = pd.to_datetime(orders_df['delivery_date'])
delivery_time = orders_df["delivery_date"] - orders_df["order_date"]
delivery_time = delivery_time.apply(lambda x: x.total_seconds())
orders_df["delivery_time"] = round(delivery_time/86400)

# %%
orders_df.describe(include="all")
# Out:
#           order_id  customer_id       payment                  order_date  \
# count  1000.000000  1000.000000   1000.000000                        1000
# mean    500.500000   506.640000  33972.936000  2021-05-27 18:38:52.800000
# min       1.000000     1.000000  10043.000000         2021-01-01 00:00:00
# 25%     250.750000   275.250000  21329.250000         2021-03-13 18:00:00
# 50%     500.500000   515.000000  33697.500000         2021-05-27 12:00:00
# 75%     750.250000   737.250000  46249.000000         2021-08-12 06:00:00
# max    1000.000000  1000.000000  59910.000000         2021-10-24 00:00:00
# std     288.819436   277.115502  14451.609047                         NaN
#
#              delivery_date  delivery_time
# count                 1000    1000.000000
# mean   2021-06-10 20:31:12      14.078000
# min    2021-01-03 00:00:00       1.000000
# 25%    2021-03-28 00:00:00       8.000000
# 50%    2021-06-11 12:00:00      14.000000
# 75%    2021-08-24 06:00:00      21.000000
# ...

# %% [markdown]
# Berdasarkan hasil tersebut, dapat diketahui bahwa rata-rata waktu pengiriman sebesar 14 hari dengan nilai maksimum sebesar 27 hari dan nilai minimum sebesar 1 hari.

# %% [markdown]
# **Eksplorasi Data orders_df dan customers_df**

# %% [markdown]
# Jika Anda perhatikan, pada data orders_df terdapat kolom yang berisi informasi terkait customer id pelanggan yang pernah melakukan order. Informasi ini bisa kita gunakan untuk mengidentifikasi pelanggan yang belum pernah melakukan order.

# %% [markdown]
# Untuk melakukan hal ini, kita bisa membuat sebuah kolom baru bernama “status” pada data customers_df. Kolom tersebut memiliki nilai “Active” untuk pelanggan yang pernah melakukan order setidaknya sekali dan sebaliknya bernilai “Non Active” untuk pelanggan yang belum pernah melakukan order sama sekali

# %%
# Convert 'order_date' and 'delivery_date' to datetime objects
orders_df['order_date'] = pd.to_datetime(orders_df['order_date'])
orders_df['delivery_date'] = pd.to_datetime(orders_df['delivery_date'])

# Calculate delivery time in days
delivery_time = orders_df["delivery_date"] - orders_df["order_date"]
delivery_time = delivery_time.apply(lambda x: x.total_seconds() / 86400)
orders_df["delivery_time"] = round(delivery_time)

# Display info to confirm type conversion and a sample of the updated DataFrame
print("Updated orders_df info:")
orders_df.info()
print("\nOrders_df head with new delivery_time:")
orders_df.head()
# Out:
# Updated orders_df info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   order_id       1000 non-null   int64
#  1   customer_id    1000 non-null   int64
#  2   payment        1000 non-null   int64
#  3   order_date     1000 non-null   datetime64[ns]
#  4   delivery_date  1000 non-null   datetime64[ns]
#  5   delivery_time  1000 non-null   float64
# dtypes: datetime64[ns](2), float64(1), int64(3)
# memory usage: 47.0 KB
#
# Orders_df head with new delivery_time:
#    order_id  customer_id  payment order_date delivery_date  delivery_time
# 0         1           64    30811 2021-08-30    2021-09-24           25.0
# 1         2          473    50490 2021-02-03    2021-02-13           10.0
# 2         3          774    46763 2021-10-08    2021-11-03           26.0
# ...

# %%
customer_id_in_orders_df =  orders_df.customer_id.tolist()
customers_df["status"] = customers_df["customer_id"].apply(lambda x: "Active" if x in customer_id_in_orders_df else "Non Active")
customers_df.sample(5)
# Out:
#      customer_id customer_name             gender  age  \
# 366          366     fulan 366  Prefer not to say   64
# 131          132     fulan 132               Male   26
# 811          808     fulan 808  Prefer not to say   35
# 201          202     fulan 202             Female   67
# 198          199     fulan 199  Prefer not to say   65
#
#                     home_address  zip_code             city  \
# 366   491 Fisher IslandSuite 745      1110        Youngview
# 131  782 King Station StApt. 193      4352        Huelmouth
# 811    4277 Ryan IslandSuite 792      4197      Robertstown
# 201   72 Lincoln SummitSuite 640      6557       Abbeyshire
# 198      94 Hannah LoopSuite 177      6219  Lake Declanland
#
#                  state    country      status
# 366           Victoria  Australia      Active
# 131    New South Wales  Australia  Non Active
# 811  Western Australia  Australia      Active
# 201         Queensland  Australia  Non Active
# ...

# %%
customers_df.groupby(by="status").customer_id.count()
# Out:
# status
# Active        617
# Non Active    384
# Name: customer_id, dtype: int64

# %% [markdown]
# Seperti yang terlihat pada pivot table di atas, terdapat cukup banyak pelanggan yang belum pernah melakukan transaksi sebelumnya. Ini tentunya merupakan data yg buruk karena hampir 30% pelanggan belum pernah melakukan order sebelumnya.

# %% [markdown]
# Untuk memperoleh lebih banyak informasi terkait kedua data tersebut, kita perlu menggabungkan keduanya melalui proses join atau merge. Berikut merupakan contoh kode untuk melakukan merge terhadap data orders_df dan customers_df.

# %%
orders_customers_df = pd.merge(
    left=orders_df,
    right=customers_df,
    how="left",
    left_on="customer_id",
    right_on="customer_id"
)
orders_customers_df.head()
# Out:
#    order_id  customer_id  payment order_date delivery_date  delivery_time  \
# 0         1           64    30811 2021-08-30    2021-09-24           25.0
# 1         2          473    50490 2021-02-03    2021-02-13           10.0
# 2         3          774    46763 2021-10-08    2021-11-03           26.0
# 3         4          433    39782 2021-05-06    2021-05-19           13.0
# 4         5          441    14719 2021-03-23    2021-03-24            1.0
#
#   customer_name             gender  age                   home_address  \
# 0      fulan 64  Prefer not to say   75      4927 Alice MeadowApt. 960
# 1     fulan 473               Male   61  531 Schmitt BoulevardApt. 010
# 2     fulan 774  Prefer not to say   34       2096 Wilson MewsApt. 714
# 3     fulan 433  Prefer not to say   46        5777 Mayer PassApt. 881
# 4     fulan 441  Prefer not to say   53   33 Richards JunctionApt. 478
#
#    zip_code                city              state    country  status
# ...

# %% [markdown]
# kita melakukan proses merge menggunakan metode left join. Metode ini memungkinkan kita untuk mengambil seluruh data dari tabel sebelah kiri, serta data yang sesuai dari tabel sebelah kanan.
#
# Dengan hasil penggabungan tersebut, terdapat banyak informasi menarik yang bisa kita eksplorasi lebih lanjut dari data di atas. Berikut ini adalah beberapa hal yang dapat kita telusuri.

# %% [markdown]
# **Jumlah order berdasarkan kota**
# Kita bisa membuat pivot table untuk memperoleh informasi terkait jumlah order berdasarkan kota dengan kode seperti berikut

# %%
orders_customers_df.groupby(by="city").order_id.nunique().sort_values(ascending=False).reset_index().head(10)
# Out:
#                city  order_id
# 0        Jordanside         6
# 1           New Ava         6
# 2  Port Hannahburgh         5
# 3         Lake Rose         5
# 4        O'keefeton         5
# 5          East Max         5
# 6          Rubyfort         5
# 7          West Kai         5
# 8         Sarahstad         4
# 9        Russelstad         4

# %% [markdown]
# berdasarkan hasil tersebut, diketahui bahwa kota Jordanside dan New Ava merupakan dua kota yang memiliki jumlah order terbanyak.

# %% [markdown]
# Jumlah order berdasarkan state
# Sekarang kita akan melihat jumlah order berdasarkan state. Untuk memperoleh informasi terkait hal ini, kita juga bisa menggunakan pivot table. Gunakan kode di bawah ini untuk menerapkannya.

# %%
orders_customers_df.groupby(by="state").order_id.nunique().sort_values(ascending=False)
# Out:
# state
# South Australia                 148
# Queensland                      139
# Western Australia               130
# New South Wales                 129
# Victoria                        118
# Australian Capital Territory    118
# Tasmania                        112
# Northern Territory              106
# Name: order_id, dtype: int64

# %% [markdown]
# Kode tersebut akan menghasilkan pivot table seperti di bawah ini. Berdasarkan pivot table tersebut, diketahui bahwa South Australia merupakan state yang paling banyak melakukan order.

# %% [markdown]
# Jumlah order berdasarkan gender
# Informasi selanjutnya yang dapat kita eksplorasi adalah jumlah order berdasarkan gender. Untuk melakukan hal ini, tentunya kita perlu membuat sebuah pivot table menggunakan kode berikut.

# %%
orders_customers_df.groupby(by="gender").order_id.nunique().sort_values(ascending=False)
# Out:
# gender
# Prefer not to say    716
# Female               139
# Male                 136
# Name: order_id, dtype: int64

# %% [markdown]
# Berdasarkan hasil tersebut, dapat dilihat bahwa kebanyakan order dilakukan oleh pelanggan yang berjenis kelamin prefer not to say. Hal ini tentunya sejalan dengan jumlah pelanggan yang kebanyakan dari kelompok gender tersebut.

# %% [markdown]
# **Jumlah order berdasarkan kelompok usia**
#
# Untuk mengeksplorasi jumlah order berdasarkan kelompok usia, kita perlu membuat sebuah kolom baru bernama age_group. Kolom ini digunakan untuk mengelompokkan pelanggan ke dalam tiga kategori usia, yaitu youth, adults, dan seniors. Setelah itu, kita dapat membuat pivot table berdasarkan kelompok usia tersebut dengan menggunakan contoh kode di bawah ini.

# %%
orders_customers_df["age_group"] = orders_customers_df.age.apply(lambda x: "Youth" if x <= 24 else ("Seniors" if x > 64 else "Adults"))

# %%
orders_customers_df.groupby(by="age_group").order_id.nunique().sort_values(ascending=False)
# Out:
# age_group
# Adults     691
# Seniors    216
# Youth       93
# Name: order_id, dtype: int64

# %% [markdown]
# Berdasarkan hasil tersebut diketahui bahwa pelanggan yang paling banyak melakukan order berasal dari kelompok usia Adults.

# %% [markdown]
# Sejauh ini kita telah menemukan banyak sekali informasi yang tentunya menarik untuk ditelusuri lebih dalam. Namun, sebelum itu mari kita mengeksplorasi dua data yang lain (product_df dan sales_df) terlebih dahulu.

# %% [markdown]
# **Eksplorasi Data product_df dan sales_df**

# %% [markdown]
# Pada tahap ini, kita akan mengeksplorasi data product_df dan sales_df. Sebagai permulaan, kita dapat melihat rangkuman parameter statistik dari keduanya menggunakan method describe().

# %%
products_df.describe(include="all")
# Out:
#          product_id product_type product_name  size colour        price  \
# count   1260.000000         1260         1260  1260   1260  1260.000000
# unique          NaN            3           35     8      7          NaN
# top             NaN        Shirt        Denim    XS    red          NaN
# freq            NaN          420           70   252    180          NaN
# mean     629.500000          NaN          NaN   NaN    NaN   105.805556
# std      363.874979          NaN          NaN   NaN    NaN     9.704423
# min        0.000000          NaN          NaN   NaN    NaN    90.000000
# 25%      314.750000          NaN          NaN   NaN    NaN    95.750000
# 50%      629.500000          NaN          NaN   NaN    NaN   108.500000
# 75%      944.250000          NaN          NaN   NaN    NaN   114.000000
# max     1259.000000          NaN          NaN   NaN    NaN   119.000000
#
#            quantity                                        description
# ...

# %% [markdown]
# Berdasarkan hasil tersebut, dapat diketahui bahwa harga produk yang dijual berada pada kisaran 90 hingga 119 dolar. Selain itu, ada informasi menarik lainnya, yaitu dalam satu kali transaksi, pelanggan paling banyak membeli tiga item dari jenis produk yang sama, dengan total harga mencapai 357 dolar.

# %% [markdown]
# Apabila Anda penasaran dengan produk yang memiliki harga termahal dan terendah, silakan jalankan kode berikut untuk melihatnya.

# %%
sales_df.describe(include="all")
# Out:
#           sales_id     order_id   product_id  price_per_unit    quantity  \
# count  5000.000000  5000.000000  5000.000000     5000.000000  5000.00000
# mean   2499.500000   503.038200   634.053200      103.501600     1.99240
# std    1443.520003   285.964418   363.255794        9.195004     0.80751
# min       0.000000     1.000000     1.000000       90.000000     1.00000
# 25%    1249.750000   258.000000   323.000000       95.000000     1.00000
# 50%    2499.500000   504.500000   635.000000      102.000000     2.00000
# 75%    3749.250000   749.000000   951.000000      112.000000     3.00000
# max    4999.000000   999.000000  1259.000000      119.000000     3.00000
#
#        total_price
# count  5000.000000
# mean    206.360000
# std      86.357457
# min      90.000000
# 25%     112.000000
# 50%     204.000000
# 75%     285.000000
# max     357.000000

# %% [markdown]
# Selanjutnya, kita bisa menggunakan pivot table untuk mencari informasi terkait produk berdasarkan tipe dan nama produknya. Berikut contoh kode yang bisa Anda gunakan.

# %%
products_df.sort_values(by="price", ascending=False)
# Out:
#       product_id product_type product_name size  colour  price  quantity  \
# 671          665       Jacket        Parka   XS     red    119        65
# 672          666       Jacket        Parka    S     red    119        66
# 673          667       Jacket        Parka    M     red    119        56
# 674          668       Jacket        Parka    L     red    119        73
# 675          669       Jacket        Parka   XL     red    119        64
# ...          ...          ...          ...  ...     ...    ...       ...
# 1222        1216     Trousers      Pleated    S  indigo     90        41
# 1229        1223     Trousers      Pleated    L  violet     90        48
# 1228        1222     Trousers      Pleated    M  violet     90        45
# 1227        1221     Trousers      Pleated    S  violet     90        50
# 1226        1220     Trousers      Pleated   XS  violet     90        58
#
#                                         description
# ...

# %%
products_df.groupby(by="product_type").agg({
    "product_id": "nunique",
    "quantity": "sum",
    "price":  ["min", "max"]
})
# Out:
#              product_id quantity price
#                 nunique      sum   min  max
# product_type
# Jacket              420    25387    90  119
# Shirt               420    25263    92  119
# Trousers            420    25139    90  119

# %%
products_df.groupby(by="product_name").agg({
    "product_id": "nunique",
    "quantity": "sum",
    "price": ["min", "max"]
})
# Out:
#                   product_id quantity price
#                      nunique      sum   min  max
# product_name
# Bomber                    35     2083    90   90
# Camp Collared             35     2071   112  112
# Cardigan                  35     2032   118  118
# Cargo Pants               35     2146   106  106
# Casual Slim Fit           35     2086   113  113
# Chambray                  35     2020   105  105
# Chinos                    35     2101   100  100
# Coach                     35     2158   115  115
# Cords                     35     2260   113  113
# Cropped                   35     2085    99   99
# Cuban Collar              35     2017    93   93
# Denim                     70     4204    92  115
# Drawstring                35     2042   104  104
# Dress                     35     2125   119  119
# Flannel                   35     2135    96   96
# Henley                    35     2051    92   92
# High-Waisted              35     2198    98   98
# ...

# %% [markdown]
# Pivot table di atas memberikan gambaran umum tentang produk-produk yang dijual oleh Fashion Collection. Sebagai calon praktisi data yang andal, tentu kita penasaran produk mana yang paling laris. Untuk menjawab pertanyaan tersebut, kita perlu menggabungkan (merge) tabel product_df dan sales_df menggunakan kode berikut.

# %%
sales_products_df = pd.merge(
    left=sales_df,
    right=products_df,
    how="left",
    left_on="product_id",
    right_on="product_id"
)
sales_products_df.head()
# Out:
#    sales_id  order_id  product_id  price_per_unit  quantity_x  total_price  \
# 0         0         1         218             106           2          212
# 1         1         1         481             118           1          118
# 2         2         1           2              96           3          288
# 3         3         1        1002             106           2          212
# 4         4         1         691             113           3          339
#
#   product_type  product_name size  colour  price  quantity_y  \
# 0        Shirt      Chambray    L  orange    105          44
# 1       Jacket        Puffer    S  indigo    110          62
# 2        Shirt  Oxford Cloth    M     red    114          54
# 3     Trousers          Wool    M    blue    111          52
# 4       Jacket         Parka    S  indigo    119          53
#
#                                    description
# 0   A orange coloured, L sized, Chambray Shirt
# 1    A indigo coloured, S sized, Puffer Jacket
# ...

# %% [markdown]
# Pada dasarnya, kode di atas digunakan untuk menggabungkan (merge) data product_df dan sales_df. Proses penggabungan ini dilakukan dengan menggunakan metode left, artinya semua data dari product_df akan tetap ditampilkan, sementara data dari sales_df akan disesuaikan berdasarkan kolom kunci yang sama. Berikut ini adalah hasil dari proses merge tersebut.

# %% [markdown]
# Jika diperhatikan kembali, hasil dari proses merge di atas memiliki perbedaan antara nilai price_per_unit dan price. Hal ini dapat terjadi karena adanya potongan harga, biaya operasional, dan biaya lainnya.

# %% [markdown]
# sekarang kita coba melihat informasi penjualan produk berdasarkan tipenya.
# dengan membuat pivot table berdasarkan produk type dengan kode berikut

# %%
sales_products_df.groupby(by="product_type").agg({
    "sales_id": "nunique",
    "quantity_x": "sum",
    "total_price": "sum"
})
# Out:
#               sales_id  quantity_x  total_price
# product_type
# Jacket            1676        3343       357026
# Shirt             1641        3259       333600
# Trousers          1683        3360       341174

# %% [markdown]
# Jika dilihat dari pivot table di atas, Trousers merupakan tipe produk yang paling laris dari segi jumlah penjualan. Namun, jika ditinjau dari revenue yang dihasilkan, justru Jacket menjadi tipe produk yang paling besar kontribusinya terhadap total pendapatan perusahaan.

# %% [markdown]
# membuat pivot table yang sama untuk melihat informasi penjualan berdasarkan nama produk menggunakan kode di bawah ini

# %%
sales_products_df.groupby(by="product_name").agg({
    "sales_id": "nunique",
    "quantity_x": "sum",
    "total_price": "sum"
}).sort_values(by="total_price", ascending=False)
# Out:
#                    sales_id  quantity_x  total_price
# product_name
# Denim                   273         527        52399
# Casual Slim Fit         154         306        36414
# Trench Coat             146         299        35581
# Shearling               150         302        35334
# Puffer                  140         298        35164
# Flannel                 141         281        33158
# Cropped                 135         284        32660
# Pleated                 147         308        32340
# Joggers                 164         334        31062
# Chambray                141         290        30740
# Parka                   134         269        30397
# Bomber                  150         297        29700
# Chinos                  135         260        29380
# Windbreaker             143         287        29274
# Cardigan                134         260        29120
# Peacoat                 132         266        28994
# ...

# %% [markdown]
# Berdasarkan pivot table tersebut, diketahui bahwa produk Denim merupakan produk yang paling laris dan juga paling banyak menyumbang revenue terhadap perusahaan.

# %% [markdown]
# **Eksplorasi Data all_df**

# %% [markdown]
# Kita perlu membuat sebuah DataFrame baru dengan nama all_df yang berfungsi untuk menampung seluruh informasi dari empat tabel yang kita miliki. DataFrame ini dibuat dengan cara menggabungkan (merge) keempat tabel tersebut. Berikut adalah contoh kode yang bisa digunakan untuk menjalankan proses penggabungan data tersebut.

# %%
all_df = pd.merge(
    left=sales_products_df,
    right=orders_customers_df,
    how="left",
    left_on="order_id",
    right_on="order_id"
)
all_df.head()
# Out:
#    sales_id  order_id  product_id  price_per_unit  quantity_x  total_price  \
# 0         0         1         218             106           2          212
# 1         1         1         481             118           1          118
# 2         2         1           2              96           3          288
# 3         3         1        1002             106           2          212
# 4         4         1         691             113           3          339
#
#   product_type  product_name size  colour  ...  customer_name  \
# 0        Shirt      Chambray    L  orange  ...       fulan 64
# 1       Jacket        Puffer    S  indigo  ...       fulan 64
# 2        Shirt  Oxford Cloth    M     red  ...       fulan 64
# 3     Trousers          Wool    M    blue  ...       fulan 64
# 4       Jacket         Parka    S  indigo  ...       fulan 64
#
#               gender age               home_address  zip_code            city  \
# ...

# %% [markdown]
# Proses merge di atas akan menghasilkan DataFrame seperti hasil di atas

# %% [markdown]
# Selanjutnya, mari kita coba lihat preferensi pembelian berdasarkan state pelanggan dan tipe produk menggunakan kode di bawah ini.

# %%
all_df.groupby(by=["state", "product_type"]).agg({
    "quantity_x": "sum",
    "total_price": "sum"
})
# Out:
#                                            quantity_x  total_price
# state                        product_type
# Australian Capital Territory Jacket               406        43204
#                              Shirt                396        40448
#                              Trousers             454        46790
# New South Wales              Jacket               451        47998
#                              Shirt                431        43980
#                              Trousers             392        39766
# Northern Territory           Jacket               365        38991
#                              Shirt                336        33865
#                              Trousers             384        38998
# Queensland                   Jacket               499        53511
#                              Shirt                417        42506
#                              Trousers             453        46045
# ...

# %% [markdown]
# Pivot table di atas menunjukkan gambaran tentang tipe produk yang paling disukai pengguna berdasarkan lokasi negara bagian. Dari grafik tersebut dapat dilihat bahwa produk Jacket (garis merah) merupakan produk yang paling banyak terjual, khususnya di negara bagian Queensland, South Australia, dan New South Wales. Sementara itu, untuk tipe produk lainnya, detail penjualannya dapat dilihat langsung pada grafik pivot table di atas.

# %% [markdown]
# Sekarang kamu bisa melakukan langkah yang sama untuk mengetahui selera atau preferensi tipe produk pelanggan berdasarkan gender dan kelompok usia. Berikut ini adalah contoh kode yang bisa kamu gunakan sebagai acuan untuk melakukan analisis tersebut.

# %%
all_df.groupby(by=["gender", "product_type"]).agg({
    "quantity_x": "sum",
    "total_price": "sum"
})
# Out:
#                                 quantity_x  total_price
# gender            product_type
# Female            Jacket               481        50963
#                   Shirt                445        45146
#                   Trousers             481        49295
# Male              Jacket               480        50978
#                   Shirt                410        41939
#                   Trousers             453        46071
# Prefer not to say Jacket              2349       251486
#                   Shirt               2386       244765
#                   Trousers            2400       243092

# %%
all_df.groupby(by=["age_group", "product_type"]).agg({
    "quantity_x": "sum",
    "total_price": "sum"
})
# Out:
#                         quantity_x  total_price
# age_group product_type
# Adults    Jacket              2332       249475
#           Shirt               2255       230907
#           Trousers            2317       235880
# Seniors   Jacket               737        78539
#           Shirt                703        71851
#           Trousers             721        72862
# Youth     Jacket               274        29012
#           Shirt                301        30842
#           Trousers             322        32432

# %% [markdown]
# Pivot table di atas bisa membantu kita melihat gambaran umum tentang selera atau preferensi tipe produk pelanggan jika dilihat dari gender dan kelompok usia. Dari tabel tersebut, kita jadi bisa mengetahui produk apa yang lebih disukai oleh kelompok demografi tertentu. Informasi ini tentunya sangat berguna untuk menjawab pertanyaan seputar preferensi pengguna berdasarkan demografi, seperti usia dan gender.

# %%
all_df.to_csv("all_data.csv", index=False)

# %%
from google.colab import files
files.download("all_data.csv")
