# %% [markdown]
# <a href="https://colab.research.google.com/github/nasywaauliya2/Pemerograman-Dasar/blob/main/Latihan-08.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Pada latihan ini, kita akan mengaplikasikan teknik data wrangling atau pembersihan data dengan menggunakan beberapa fungsi atau method yang sudah di bahas pada teori sebelumnya, jadi hasilnya adalah data yang bersih dan siap digunakan.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# **Memuat tabel** dan membuat dataframe

# %%
nasywa_df = pd.read_csv('/content/mahasiswa (1).csv')
display(nasywa_df.head())
# Out:
#      nim   nama           jurusan    umur nilai_akhir  kehadiran_pct  \
# 0  E0001   Aldi            Teknik     150        59.5           82.0
# 1  E0002   Budi            teknik    20.0        84.5           99.0
# 2  E0003  Citra            Energi      -5        56.2           78.0
# 3  E0004   Dewi            Teknik  twenty        63.0           99.0
# 4  E0005    Eka  Manajemen Energi    22.0         999           65.0
#
#   tanggal_daftar
# 0     2024-05-05
# 1     2024-02-14
# 2     2024-04-29
# 3     2024-08-02
# 4     2024-03-22

# %% [markdown]
# **Load table**

# %%
nasywa_df.head()
#melihat 5 data teratas
# Out:
#      nim   nama           jurusan    umur nilai_akhir  kehadiran_pct  \
# 0  E0001   Aldi            Teknik     150        59.5           82.0
# 1  E0002   Budi            teknik    20.0        84.5           99.0
# 2  E0003  Citra            Energi      -5        56.2           78.0
# 3  E0004   Dewi            Teknik  twenty        63.0           99.0
# 4  E0005    Eka  Manajemen Energi    22.0         999           65.0
#
#   tanggal_daftar
# 0     2024-05-05
# 1     2024-02-14
# 2     2024-04-29
# 3     2024-08-02
# 4     2024-03-22

# %%
nasywa_df.tail()
#melihat 5 data terakhir
# Out:
#       nim   nama      jurusan  umur nilai_akhir  kehadiran_pct tanggal_daftar
# 73  E0057  Fauzi       Energi  23.0        58.2           76.0     2024-02-05
# 74  E0039   Mita       Energi  23.0        77.2           79.0     2024-01-04
# 75  E0069  Salsa  Informatika  23.0        63.4           86.0     2024-04-14
# 76  E0031   Eros  Informatika  23.0        68.0           66.0     2024-02-27
# 77  E0026   Zara  Informatika  24.0        90.4           82.0     2024-11-24

# %% [markdown]
# **Assessing Data**

# %%
nasywa_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 78 entries, 0 to 77
# Data columns (total 7 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   nim             78 non-null     object
#  1   nama            78 non-null     object
#  2   jurusan         76 non-null     object
#  3   umur            76 non-null     object
#  4   nilai_akhir     76 non-null     object
#  5   kehadiran_pct   76 non-null     float64
#  6   tanggal_daftar  76 non-null     object
# dtypes: float64(1), object(6)
# memory usage: 4.4+ KB

# %% [markdown]
# Dataset berisi 78 baris dan 7 kolom, namun beberapa kolom seperti jurusan, umur, nilai_akhir, kehadiran_pct, dan tanggal_daftar masih memiliki missing value dan tipe datanya belum sesuai. Karena itu, dataset perlu dibersihkan dan diperbaiki sebelum digunakan untuk analisis lebih lanjut.

# %%
nasywa_df.isna().sum()
# Out:
# nim               0
# nama              0
# jurusan           2
# umur              2
# nilai_akhir       2
# kehadiran_pct     2
# tanggal_daftar    2
# dtype: int64

# %% [markdown]
# Terdapat 5 kolom yang memiliki nilai kosong, dan masing-masing memiliki 2 missing value. Kehadiran missing value ini menunjukkan bahwa dataset belum sepenuhnya bersih dan masih memerlukan proses data cleaning.

# %%
print("Jumlah duplikasi: ", nasywa_df.duplicated().sum())
# Out:
# Jumlah duplikasi:  8

# %% [markdown]
# Fungsi duplicated() menandai setiap baris yang memiliki isi sama dengan baris sebelumnya, lalu .sum() menghitung jumlah baris yang ditandai sebagai duplikat. Hasil output “8” berarti terdapat 8 baris data yang terdeteksi sebagai duplikasi.

# %% [markdown]
# **Cleaning Data**

# %%
nasywa_df.drop_duplicates(inplace=True)

# %%
print("Jumlah duplikasi: ", nasywa_df.duplicated().sum())
# Out:
# Jumlah duplikasi:  0

# %% [markdown]
# Setelah drop_duplicates(), pengecekan ulang menunjukkan jumlah duplikasi menjadi 0, artinya data sudah bersih dari baris yang kembar.

# %% [markdown]
# **Menangani missing value**

# %%
nasywa_df.isna().sum()
# Out:
# nim               0
# nama              0
# jurusan           2
# umur              2
# nilai_akhir       2
# kehadiran_pct     2
# tanggal_daftar    2
# dtype: int64

# %%
nasywa_df['jurusan'] = nasywa_df['jurusan'].fillna('Pembangkit Energi')

# %%
nasywa_df.isna().sum()
# Out:
# nim               0
# nama              0
# jurusan           0
# umur              2
# nilai_akhir       2
# kehadiran_pct     2
# tanggal_daftar    2
# dtype: int64

# %%
nasywa_df['umur'] = nasywa_df['umur'].fillna(23)

# %%
nasywa_df.isna().sum()
# Out:
# nim               0
# nama              0
# jurusan           0
# umur              0
# nilai_akhir       2
# kehadiran_pct     2
# tanggal_daftar    2
# dtype: int64

# %%
nasywa_df['umur'] = nasywa_df['umur'].fillna(23)

# %%
nasywa_df.isna().sum()
# Out:
# nim               0
# nama              0
# jurusan           0
# umur              0
# nilai_akhir       2
# kehadiran_pct     2
# tanggal_daftar    2
# dtype: int64

# %%
nasywa_df['nilai_akhir'] = pd.to_numeric(nasywa_df['nilai_akhir'], errors='coerce') #konversi tipe data menjadi numeric yaitu float

nasywa_df['nilai_akhir'].mean() #mecari rata-rata
# Out:
# np.float64(88.15384615384616)

# %%
nasywa_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 70 entries, 0 to 69
# Data columns (total 7 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   nim             70 non-null     object
#  1   nama            70 non-null     object
#  2   jurusan         70 non-null     object
#  3   umur            70 non-null     object
#  4   nilai_akhir     65 non-null     float64
#  5   kehadiran_pct   68 non-null     float64
#  6   tanggal_daftar  68 non-null     object
# dtypes: float64(2), object(5)
# memory usage: 4.4+ KB

# %% [markdown]
# Output tersebut menampilkan ringkasan DataFrame nasywa_df: total 70 baris, 7 kolom, beberapa kolom masih berisi nilai kosong, dan tipe data tiap kolom ditampilkan. Ringkasan ini membantu melihat kondisi data sebelum dibersihkan. data sudah berubah jadi float

# %%
nasywa_df['nilai_akhir'] = nasywa_df['nilai_akhir'].fillna(88)

# %%
nasywa_df.isna().sum()
# Out:
# nim               0
# nama              0
# jurusan           0
# umur              0
# nilai_akhir       5
# kehadiran_pct     2
# tanggal_daftar    2
# dtype: int64

# %% [markdown]
# **Lakukan untuk kolom Kehadiran**

# %%
nasywa_df['kehadiran_pct'] = pd.to_numeric(nasywa_df['kehadiran_pct'], errors='coerce') #konversi tipe data menjadi numeric yaitu float

nasywa_df['kehadiran_pct'].mean() #mecari rata-rata
# Out:
# np.float64(82.13235294117646)

# %%
nasywa_df['kehadiran_pct'] = mhs_df['kehadiran_pct'].fillna(82)

# %%
nasywa_df.isna().sum()
# Out:
# nim               0
# nama              0
# jurusan           0
# umur              0
# nilai_akhir       5
# kehadiran_pct     0
# tanggal_daftar    2
# dtype: int64

# %% [markdown]
# **Lakukan untuk kolom Kehadiran**

# %%
nasywa_df['kehadiran_pct'] = pd.to_numeric(nasywa_df['kehadiran_pct'], errors='coerce') #konversi tipe data menjadi numeric yaitu float

nasywa_df['kehadiran_pct'].mean() #mecari rata-rata
# Out:
# np.float64(82.12857142857143)

# %%
nasywa_df['kehadiran_pct'] = nasywa_df['kehadiran_pct'].fillna(82)

# %%
nasywa_df.isna().sum()
# Out:
# nim               0
# nama              0
# jurusan           0
# umur              0
# nilai_akhir       5
# kehadiran_pct     0
# tanggal_daftar    2
# dtype: int64

# %% [markdown]
# Lakukan untuk kolom tanggal daftar

# %%
nasywa_df['tanggal_daftar'] = nasywa_df['tanggal_daftar'].fillna('2024-03-24')

# %%
nasywa_df.isna().sum()
# Out:
# nim               0
# nama              0
# jurusan           0
# umur              0
# nilai_akhir       5
# kehadiran_pct     0
# tanggal_daftar    0
# dtype: int64

# %% [markdown]
# Sekarang tidak ada lagi data missing atau NaN

# %% [markdown]
# **Menangani inaccurate value**

# %%
nasywa_df.jurusan.value_counts()
# Out:
# jurusan
# Energi               21
# Informatika          17
# Teknik               12
# Manajemen Energi     11
# Pembangkit Energi     2
# teknik                1
#  energi               1
# ManajemenEnergi       1
# EnErGi                1
# Teknik                1
# ENG                   1
# ENERGI                1
# Name: count, dtype: int64

# %%
nasywa_df.umur.value_counts()
# Out:
# umur
# 23.0          15
# 25.0          10
# 20.0           9
# 24.0           9
# 22.0           8
# 19.0           7
# 21.0           4
# 23             2
# 150            1
# twenty         1
# -5             1
# 120            1
# NaN_string     1
# 21years        1
# Name: count, dtype: int64

# %% [markdown]
# Terdapat 2 kolom yang datanya tidak akurat atau inaccurate value

# %%
nasywa_df['jurusan'] = nasywa_df['jurusan'].str.lower().str.strip()

# %%
nasywa_df.jurusan.value_counts()
# Out:
# jurusan
# energi               24
# informatika          17
# teknik               14
# manajemen energi     11
# pembangkit energi     2
# manajemenenergi       1
# eng                   1
# Name: count, dtype: int64

# %%
mapping_jurusan = {
    "energi": "Pembangkit Energi",
    " energi ": "Pembangkit Energi",
    "ENERGI": "Pembangkit Energi",
    "EnErGi": "Pembangkit Energi",
    "eng": "Pembangkit Energi",
    "teknik": "Pembangkit Energi",
    "Teknik ": "Pembangkit Energi",
    "teknik ": "Pembangkit Energi",
    "manajemenenergi": "Manajemen Energi",
    "manajemen energi": "Manajemen Energi"
}

# %%
nasywa_df["jurusan"] = nasywa_df["jurusan"].str.title()

# %%
nasywa_df.jurusan.value_counts()
# Out:
# jurusan
# Energi               24
# Informatika          17
# Teknik               14
# Manajemen Energi     11
# Pembangkit Energi     2
# Manajemenenergi       1
# Eng                   1
# Name: count, dtype: int64

# %%
print("Hasil setelah normalisasi dan pemetaan:")
print(nasywa_df['jurusan'].value_counts())
# Out:
# Hasil setelah normalisasi dan pemetaan:
# jurusan
# Energi               24
# Informatika          17
# Teknik               14
# Manajemen Energi     11
# Pembangkit Energi     2
# Manajemenenergi       1
# Eng                   1
# Name: count, dtype: int64

# %% [markdown]
# Sekarang untuk inaccurate value pada kolom jurusan sudah selesai adan tidak data type atau tidak terkelompok dengan benar

# %% [markdown]
# **Selanjutnya lakuakan untuk kolom nilai **

# %%
nasywa_df.umur.value_counts()
# Out:
# umur
# 23.0          15
# 25.0          10
# 20.0           9
# 24.0           9
# 22.0           8
# 19.0           7
# 21.0           4
# 23             2
# 150            1
# twenty         1
# -5             1
# 120            1
# NaN_string     1
# 21years        1
# Name: count, dtype: int64

# %% [markdown]
# di sini dapat kita ketahui beberapa data yang tidak konsisten seperti (150, -5, twenty, 120,NaN_string, 21years
#
# Selanjutnya lakukan seperti pada kolom jurusan , bisa di lakukan mapping atau di ganti dengan satu persatu, karena di sini jumlah data yg inkonsisten hanya satum jadi bisa di replace saja

# %%
nasywa_df['umur'] = nasywa_df['umur'].replace('twenty', 20)

# %%
print(nasywa_df['umur'].value_counts())
# Out:
# umur
# 23.0          15
# 25.0          10
# 20.0           9
# 24.0           9
# 22.0           8
# 19.0           7
# 21.0           4
# 23             2
# 150            1
# 20             1
# -5             1
# 120            1
# NaN_string     1
# 21years        1
# Name: count, dtype: int64

# %% [markdown]
# Bisa di lakuakn replace satu persatu seperti di atas atau mapping kembali seperti jurusan sebelumnya

# %%
"""mapping_umur = {
    'twenty': 20,
    '21years': 21,
    'NaN_string': np.nan,
    -5: np.nan,
    120: np.nan,
    150: np.nan
}
"""
# Out:
# "mapping_umur = {\n    'twenty': 20,\n    '21years': 21,\n    'NaN_string': np.nan,\n    -5: np.nan,\n    120: np.nan,\n    150: np.nan\n}\n"

# %%
nasywa_df['umur'] = pd.to_numeric(nasywa_df['umur'], errors='coerce')
nasywa_df['umur'].mean()
# Out:
# np.float64(25.220588235294116)

# %% [markdown]
# Sekarang setelah di konversi menjadi numerik maka di dapat nilai rata-rata, dan selanjutnya isikan pada mappinganya

# %%
mapping_umur = {
    'twenty': 20,
    '21years': 21,
    'NaN_string': 25,
    -5: 25,
    120: 25,
    150: 25
}

# %%
nasywa_df['umur'] = nasywa_df['umur'].replace(mapping_umur)

# %%
print("Hasil setelah pemetaan:")
print(mhs_df['umur'].value_counts())
print(f"\nTipe data kolom 'umur' sekarang: {mhs_df['umur'].dtype}")
# Out:
# Hasil setelah pemetaan:
# umur
# 23.0          19
# 25.0          12
# 24.0          11
# 20.0           9
# 22.0           8
# 19.0           7
# 21.0           4
# 150            1
# -5             1
# twenty         1
# 120            1
# NaN_string     1
# 21years        1
# Name: count, dtype: int64
#
# Tipe data kolom 'umur' sekarang: object

# %% [markdown]
# Sekarang kolom umur sudah tidak ada lagi data yg inaccruate,tetapi harus di pastikan lagi seperti di bawah ini

# %%
nasywa_df.isna().sum()
# Out:
# nim               0
# nama              0
# jurusan           0
# umur              2
# nilai_akhir       5
# kehadiran_pct     0
# tanggal_daftar    0
# dtype: int64

# %%
nasywa_df.head(50)
# Out:
#       nim    nama            jurusan        umur nilai_akhir  kehadiran_pct  \
# 0   E0001    Aldi             Teknik         150        59.5           82.0
# 1   E0002    Budi             teknik        20.0        84.5           99.0
# 2   E0003   Citra             Energi          -5        56.2           78.0
# 3   E0004    Dewi             Teknik      twenty        63.0           99.0
# 4   E0005     Eka   Manajemen Energi        22.0         999           65.0
# 5   E0006   Fajar             Energi        21.0         -20           78.0
# 6   E0007    Gina        Informatika        19.0        70.2          150.0
# 7   E0008  Hendra             Energi        25.0        56.7          -10.0
# 8   E0009     Ika        Informatika         120        58.2           83.0
# 9   E0010    Joko             Teknik        23.0        62.7           69.0
# 10  E0011    Kiki             Energi        25.0        66.6           70.0
# ...

# %%
nasywa_df.tail(50)
# Out:
#       nim    nama            jurusan  umur  nilai_akhir  kehadiran_pct  \
# 20  E0021     Uli             Teknik  24.0         78.4           90.0
# 21  E0022    Vina             Energi   NaN         75.4           70.0
# 22  E0023   Wawan             Energi  20.0         80.1           92.0
# 23  E0024    Xena        Informatika  22.0         70.3           94.0
# 24  E0025    Yudi  Pembangkit Energi  23.0         89.4           65.0
# 25  E0026    Zara        Informatika  24.0         90.4           82.0
# 26  E0027    Arif             Energi  19.0         66.7           75.0
# 27  E0028    Bima             Teknik  24.0         90.0           81.0
# 28  E0029    Cici             Teknik  23.0         91.5           84.0
# 29  E0030    Dani             Energi  20.0          NaN           75.0
# 30  E0031    Eros        Informatika  23.0         68.0           66.0
# 31  E0032   Ferry             Teknik  25.0         87.3           80.0
# ...

# %% [markdown]
# terdapat Missing value pada baris 21 dan 54
#
# untuk itu bisa di lakukan replace lagi dengan memasukan rata-rata umur seperti sebelumnya

# %%
nasywa_df['umur'].mean() #mencari rata-rata
# Out:
# np.float64(22.426470588235293)

# %%
nasywa_df['umur'] = mhs_df['umur'].fillna(22) #isi dengan nilai rata-rata

# %%
nasywa_df.isna().sum()
# Out:
# nim               0
# nama              0
# jurusan           0
# umur              0
# nilai_akhir       5
# kehadiran_pct     0
# tanggal_daftar    0
# dtype: int64

# %% [markdown]
# Setelah di cek sudah tidak ada lagi data yang missing pada semua kolom data

# %%
nasywa_df.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# Untuk pulikat juga sama tidak ada data yang duplikat

# %% [markdown]
# Untuk memverifikasi bisa show head() dan tail() seperti di bawah ini atau count duplicates() dan isnan()

# %%
nasywa_df.head(55)
# Out:
#       nim    nama            jurusan        umur  nilai_akhir  kehadiran_pct  \
# 0   E0001    Aldi             Teknik         150         59.5           82.0
# 1   E0002    Budi             Teknik        20.0         84.5           99.0
# 2   E0003   Citra             Energi          -5         56.2           78.0
# 3   E0004    Dewi             Teknik      twenty         63.0           99.0
# 4   E0005     Eka   Manajemen Energi        22.0        999.0           65.0
# 5   E0006   Fajar             Energi        21.0        -20.0           78.0
# 6   E0007    Gina        Informatika        19.0         70.2          150.0
# 7   E0008  Hendra             Energi        25.0         56.7          -10.0
# 8   E0009     Ika        Informatika         120         58.2           83.0
# 9   E0010    Joko             Teknik        23.0         62.7           69.0
# 10  E0011    Kiki             Energi        25.0         66.6           70.0
# ...

# %%
nasywa_df.tail()
# Out:
#       nim   nama           jurusan  umur  nilai_akhir  kehadiran_pct  \
# 65  E0066   Oleh            Energi  23.0         94.4           98.0
# 66  E0067  Putri            Energi  24.0         59.1           82.0
# 67  E0068   Rafi       Informatika  19.0         84.7           74.0
# 68  E0069  Salsa       Informatika  23.0         63.4           86.0
# 69  E0070  Tasya  Manajemen Energi  23.0         74.5           68.0
#
#    tanggal_daftar
# 65     2024-01-05
# 66     2024-05-15
# 67     2024-05-19
# 68     2024-04-14
# 69     2024-02-17

# %%
nasywa_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 70 entries, 0 to 69
# Data columns (total 7 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   nim             70 non-null     object
#  1   nama            70 non-null     object
#  2   jurusan         70 non-null     object
#  3   umur            70 non-null     object
#  4   nilai_akhir     65 non-null     float64
#  5   kehadiran_pct   70 non-null     float64
#  6   tanggal_daftar  70 non-null     object
# dtypes: float64(2), object(5)
# memory usage: 4.4+ KB

# %% [markdown]
# JIka di lihat pada info, maka semua jumlah data sama yaitu 70, maka proses Pembersihan data sudah selesai

# %% [markdown]
# Export data yang sudah di bersihkan menjadi file csv, menggunakan script berikut ini

# %%
nasywa_df.to_csv("mahasiswa_clean.csv", index=False)

# %% [markdown]
# Lalu lakukan Dodownload file csv yang sudah di export sebelumnya

# %%
from google.colab import files
files.download("mahasiswa_clean.csv")

# %% [markdown]
# Bandingkan hasil data csv sebelumnya dengan csv yang sudah di bersihkan bisa di buka menggunakan excel / spreadsheet untuk membandingaknya

# %% [markdown]
# **Silahkan di jelskan langkah-langkah dan hasil latihan pada laporan**

# %%
test_df = pd.read_csv("/content/sample_data/california_housing_train.csv")

# %%
test_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17000 entries, 0 to 16999
# Data columns (total 9 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           17000 non-null  float64
#  1   latitude            17000 non-null  float64
#  2   housing_median_age  17000 non-null  float64
#  3   total_rooms         17000 non-null  float64
#  4   total_bedrooms      17000 non-null  float64
#  5   population          17000 non-null  float64
#  6   households          17000 non-null  float64
#  7   median_income       17000 non-null  float64
#  8   median_house_value  17000 non-null  float64
# dtypes: float64(9)
# memory usage: 1.2 MB

# %%
test_df.describe()
# Out:
#           longitude      latitude  housing_median_age   total_rooms  \
# count  17000.000000  17000.000000        17000.000000  17000.000000
# mean    -119.562108     35.625225           28.589353   2643.664412
# std        2.005166      2.137340           12.586937   2179.947071
# min     -124.350000     32.540000            1.000000      2.000000
# 25%     -121.790000     33.930000           18.000000   1462.000000
# 50%     -118.490000     34.250000           29.000000   2127.000000
# 75%     -118.000000     37.720000           37.000000   3151.250000
# max     -114.310000     41.950000           52.000000  37937.000000
#
#        total_bedrooms    population    households  median_income  \
# count    17000.000000  17000.000000  17000.000000   17000.000000
# mean       539.410824   1429.573941    501.221941       3.883578
# std        421.499452   1147.852959    384.520841       1.908157
# min          1.000000      3.000000      1.000000       0.499900
# ...

# %%
test_df.head(60)
# Out:
#     longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0     -114.31     34.19                15.0       5612.0          1283.0
# 1     -114.47     34.40                19.0       7650.0          1901.0
# 2     -114.56     33.69                17.0        720.0           174.0
# 3     -114.57     33.64                14.0       1501.0           337.0
# 4     -114.57     33.57                20.0       1454.0           326.0
# 5     -114.58     33.63                29.0       1387.0           236.0
# 6     -114.58     33.61                25.0       2907.0           680.0
# 7     -114.59     34.83                41.0        812.0           168.0
# 8     -114.59     33.61                34.0       4789.0          1175.0
# 9     -114.60     34.83                46.0       1497.0           309.0
# 10    -114.60     33.62                16.0       3741.0           801.0
# 11    -114.60     33.60                21.0       1988.0           483.0
# ...
